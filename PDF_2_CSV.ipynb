# %%
from tabula import read_pdf
from tabula import convert_into
import pandas as pd
import numpy as np    
import tabula

# %%
df=read_pdf("C:/Users/shruti.kerkar/Downloads/Mahyesh/273_KAGAL/KAGAL1.PDF",pages="all",multiple_tables=True)

# %%
type(df)
# Out:
# list

# %%
read_pdf("C:/Users/shruti.kerkar/Downloads/Mahyesh/273_KAGAL/KAGAL1.PDF", pages="all",multiple_tables=True, output_format="csv")
# Out:
# [                                                    0         1  ...                                   3     4
#  0          णवधधनसभध  मतदधरसघधचध कमधक व नधव  :273 कसगल       NaN  ...                            यधदत भधग   NaN
#  1                                   आणण आरकण  सससतत :  सरससधसरण  ...                                 NaN     1
#  2              णवधधनसभध मतदधरसघ जयध ललकसभध मतदधरसघधत:       NaN  ...                                 NaN   NaN
#  3           अतभत आह तयध ललकसभध मतदधरसघधचध कमधक  व नधव       NaN  ...                                 NaN   NaN
#  4                                   आणण आरकण  सससतत :       NaN  ...                                 NaN   NaN
#  5                                  1. पनणरकणधचध तपशतल       NaN  ...                                 NaN   NaN
#  6                                    पनणरकण वर : 2019       NaN  ...                                 NaN   NaN
# ...

# %%
tabula.convert_into("C:/Users/shruti.kerkar/Downloads/Mahyesh/273_KAGAL/KAGAL1.PDF",
                    "C:/Users/shruti.kerkar/Downloads/pdf2csv.csv",
                    pages="all",multiple_tables=True)
#dataframe=pd.DataFrame(df)
#dataframe = pd.DataFrame(np.array(df), columns=columns)

# %%
#dataframe.head()

# %%
#df[4].to_csv('C:/Users/shruti.kerkar/Downloads/all.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-e71379836282> in <module>()
# ----> 1 df[4:].to_csv('C:/Users/shruti.kerkar/Downloads/all.csv', encoding='utf-8')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
colnames=['a','b','c','d','e','f','g','h','i']
a_file = pd.read_csv('C:/Users/shruti.kerkar/Desktop/kagalcsv.csv',encoding='utf-8',names=colnames,header=None)

# %%
a_file.isnull().sum()
# Out:
# a      13
# b    1568
# c      48
# d     523
# e    1379
# f     366
# g    2283
# h     441
# i    1580
# dtype: int64

# %%
new_a_file=a_file.drop(columns=['b','e','f','g','i'],axis=1)
new_a_file
# Out:
#                                                       a   ...    location
# 0            ????????  ?????????? ???? ? ???  :273 ????   ...         NaN
# 1                                     ??? ????  ????? :   ...         NaN
# 2                ???????? ??????? ??? ?????? ?????????:   ...         NaN
# 3             ???? ?? ??? ?????? ?????????? ????  ? ???   ...         NaN
# 4                                     ??? ????  ????? :   ...         NaN
# 5                                    1. ????????? ?????   ...         NaN
# 6                                      ?????? ?? : 2019   ...         NaN
# 7                               ???? ????? : 01/01/2019   ...         NaN
# 8                           ???????? ???? : ???? ??????   ...         NaN
# 9                                                   NaN   ...         NaN
# 10                           ??????? ????? : 01/09/2018   ...         NaN
# 11                       2. ???? ??? ??? ????? ?? ?????   ...         NaN
# ...

# %%
df_no_missing=new_a_file.dropna()
df_no_missing
# Out:
# Empty DataFrame
# Columns: [a, c, d, h, location]
# Index: []

# %%
df_cleaned =new_a_file.dropna(axis=1,how='all')
df_cleaned
# Out:
#                                                       a ...     h
# 0            ????????  ?????????? ???? ? ???  :273 ???? ...   NaN
# 1                                     ??? ????  ????? : ...   NaN
# 2                ???????? ??????? ??? ?????? ?????????: ...   NaN
# 3             ???? ?? ??? ?????? ?????????? ????  ? ??? ...   NaN
# 4                                     ??? ????  ????? : ...   NaN
# 5                                    1. ????????? ????? ...   NaN
# 6                                      ?????? ?? : 2019 ...   NaN
# 7                               ???? ????? : 01/01/2019 ...   NaN
# 8                           ???????? ???? : ???? ?????? ...   NaN
# 9                                                   NaN ...   NaN
# 10                           ??????? ????? : 01/09/2018 ...   NaN
# 11                       2. ???? ??? ??? ????? ?? ????? ...   NaN
# 12    ???? ??????? ????? ????? : 1.?????? ????? ????... ...   NaN
# ...

# %%
new_a_file.dropna(axis=1, how='all')
# Out:
#                                                       a ...     h
# 0            ????????  ?????????? ???? ? ???  :273 ???? ...   NaN
# 1                                     ??? ????  ????? : ...   NaN
# 2                ???????? ??????? ??? ?????? ?????????: ...   NaN
# 3             ???? ?? ??? ?????? ?????????? ????  ? ??? ...   NaN
# 4                                     ??? ????  ????? : ...   NaN
# 5                                    1. ????????? ????? ...   NaN
# 6                                      ?????? ?? : 2019 ...   NaN
# 7                               ???? ????? : 01/01/2019 ...   NaN
# 8                           ???????? ???? : ???? ?????? ...   NaN
# 9                                                   NaN ...   NaN
# 10                           ??????? ????? : 01/09/2018 ...   NaN
# 11                       2. ???? ??? ??? ????? ?? ????? ...   NaN
# 12    ???? ??????? ????? ????? : 1.?????? ????? ????... ...   NaN
# ...

# %%
new_a_file.dropna(thresh=5)
# Out:
# Empty DataFrame
# Columns: [a, c, d, h, location]
# Index: []

# %%
str_cols = ['a','c','d','h']    # specify columns you want to replace
new_a_file[str_cols] = new_a_file[str_cols].replace('?', '', regex=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-224-74b4a43380af> in <module>()
#       1 str_cols = ['a','c','d','h']    # specify columns you want to replace
# ----> 2 new_a_file[str_cols] = new_a_file[str_cols].replace('?', '', regex=True)
#
# ~\Downloads\anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3796                                               value=value, inplace=inplace,
#    3797                                               limit=limit, regex=regex,
# -> 3798                                               method=method)
#    3799
#    3800     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Downloads\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
# ...

# %%
#f[df['Unnamed: 1'].notnull() & df['Unnamed: 2'].notnull()]
a_file.dropna(axis=1, how='all')
# Out:
#                                                       a          b ...     h    i
# 0            ????????  ?????????? ???? ? ???  :273 ????        NaN ...   NaN  NaN
# 1                                     ??? ????  ????? :   ???????? ...   NaN  NaN
# 2                ???????? ??????? ??? ?????? ?????????:        NaN ...   NaN  NaN
# 3             ???? ?? ??? ?????? ?????????? ????  ? ???        NaN ...   NaN  NaN
# 4                                     ??? ????  ????? :        NaN ...   NaN  NaN
# 5                                    1. ????????? ?????        NaN ...   NaN  NaN
# 6                                      ?????? ?? : 2019        NaN ...   NaN  NaN
# 7                               ???? ????? : 01/01/2019        NaN ...   NaN  NaN
# 8                           ???????? ???? : ???? ??????        NaN ...   NaN  NaN
# 9                                                   NaN        NaN ...   NaN  NaN
# ...

# %%
a_file.dropna(thresh=5)

#a_file[a_file['a'].notnull() & a_file['c'].notnull()]
# Out:
#                                    a          b   ...             i location
# 30                      1 HZV1075175        NaN   ...           NaN      NaN
# 31         ??????? ?? : ????? ??????        NaN   ...           NaN      NaN
# 33         ?????? ??? : ????? ??????      Photo   ...         Photo      NaN
# 34                        ?? ????: 2  Available   ...     Available      NaN
# 35              43?? : 47 ? ?  : ???        NaN   ...           NaN      NaN
# 36                      4 HZV1075381        NaN   ...           NaN      NaN
# 37      ??????? ?? : ????? ??? ?????        NaN   ...           NaN      NaN
# 39            ???? ??? : ????? ?????      Photo   ...         Photo      NaN
# 40                        ?? ????: 2  Available   ...     Available      NaN
# 41              20?? : 38 ? ?  : ???        NaN   ...           NaN      NaN
# 42               7 MT/48/286/0000118        NaN   ...           NaN      NaN
# ...

# %%
a_file.fillna(0)
# Out:
#                                                       a          b   ...     i location
# 0            ????????  ?????????? ???? ? ???  :273 ????          0   ...     0      0.0
# 1                                     ??? ????  ????? :   ????????   ...     0      0.0
# 2                ???????? ??????? ??? ?????? ?????????:          0   ...     0      0.0
# 3             ???? ?? ??? ?????? ?????????? ????  ? ???          0   ...     0      0.0
# 4                                     ??? ????  ????? :          0   ...     0      0.0
# 5                                    1. ????????? ?????          0   ...     0      0.0
# 6                                      ?????? ?? : 2019          0   ...     0      0.0
# 7                               ???? ????? : 01/01/2019          0   ...     0      0.0
# 8                           ???????? ???? : ???? ??????          0   ...     0      0.0
# 9                                                     0          0   ...     0      0.0
# ...

# %%
a_file[''].head(200)
# Out:
# 0            NaN
# 1       ????????
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           ? ?
# 29           585
#          ...
# 170          NaN
# 171        Photo
# 172    Available
# 173          NaN
# 174          NaN
# 175          NaN
# 176          NaN
# 177        Photo
# 178    Available
# 179          NaN
# 180          NaN
# 181          NaN
# 182          NaN
# 183        Photo
# 184    Available
# 185          NaN
# 186          NaN
# 187          NaN
# 188          NaN
# 189        Photo
# 190    Available
# ...

# %%
new_a=a_file.a.str.replace('?','')
print(new_a.head(100))
# Out:
# 0                                :273
# 1                                    :
# 2                                    :
# 3
# 4                                    :
# 5                                 1.
# 6                               : 2019
# 7                         : 01/01/2019
# 8                                  :
# 9                                  NaN
# 10                        : 01/09/2018
# 11                            2.
# 12             : 1.   ,2.   ,3.  ,4.
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                             3.    :
# 19                                 : 1
# 20                                 NaN
# 21                         :       . 1
# 22                                 NaN
# 23                                 NaN
# 24                              4.   :
# ...

# %%
new_h=a_file.h.str.replace('?','')
new_h.head(100)
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
#          ...
# 70           : 4
# 71            :
# 72    HZV1086578
# 73          :
# 74           NaN
# 75           :
# 76           : 5
# 77            :
# 78    HZV1077833
# 79          :
# 80           NaN
# 81           :
# 82           : 5
# 83            :
# 84    NZF1000132
# 85           :
# 86
# 87           :
# 88           : 6
# 89            :
# 90    HZV1076702
# 91          :
# 92           NaN
# ...

# %%
new_d=a_file.d.str.replace('?','')
new_d.head(100)
type(new_a)
# Out:
# pandas.core.series.Series

# %%
a_file['a'].head(100)
# Out:
# 0            ????????  ?????????? ???? ? ???  :273 ????
# 1                                     ??? ????  ????? :
# 2                ???????? ??????? ??? ?????? ?????????:
# 3             ???? ?? ??? ?????? ?????????? ????  ? ???
# 4                                     ??? ????  ????? :
# 5                                    1. ????????? ?????
# 6                                      ?????? ?? : 2019
# 7                               ???? ????? : 01/01/2019
# 8                           ???????? ???? : ???? ??????
# 9                                                   NaN
# 10                           ??????? ????? : 01/09/2018
# 11                       2. ???? ??? ??? ????? ?? ?????
# 12    ???? ??????? ????? ????? : 1.?????? ????? ????...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
a_file[a_file['new_a'].notnull() & a_file['new_d'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Downloads\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_a'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-207-bc4f998f4842> in <module>()
# ...
